# %% [markdown]
# # 1. bfv (bed-full-view)

# %%
from evaluator import CompleteGroundedSAM2Evaluator

# 파일 경로 설정
coco_annotations_path = "my_dataset/bfv/labels/bfv-labels_COCO-format.json"
grounded_sam2_results_dir = "outputs/PID4/CID5/bfv"

# 평가기 생성 및 실행
evaluator = CompleteGroundedSAM2Evaluator(coco_annotations_path, grounded_sam2_results_dir)
results = evaluator.run_evaluation()

if results:
    print("\n전체 평가가 완료되었습니다!")
else:
    print("\n평가 중 오류가 발생했습니다.")
# Out:
# 총 10개 이미지 평가 시작...
# ...
# 평가 중: 1/10 - bfv10_grounded_sam2_results.json
#   - GT: 9, Pred: 10
#   - BBox: P=0.7000, R=0.7778, F1=0.7368
#   - Mask: P=0.5000, R=0.5556, F1=0.5263
#   - Combined: P=0.5000, R=0.5556, F1=0.5263
#   - Pixel-level IoU: 0.5432
# 평가 중: 2/10 - bfv1_grounded_sam2_results.json
#   - GT: 14, Pred: 12
#   - BBox: P=1.0000, R=0.8571, F1=0.9231
#   - Mask: P=0.9167, R=0.7857, F1=0.8462
#   - Combined: P=0.9167, R=0.7857, F1=0.8462
#   - Pixel-level IoU: 0.8851
# 평가 중: 3/10 - bfv2_grounded_sam2_results.json
#   - GT: 15, Pred: 12
#   - BBox: P=1.0000, R=0.8000, F1=0.8889
#   - Mask: P=0.8333, R=0.6667, F1=0.7407
#   - Combined: P=0.8333, R=0.6667, F1=0.7407
#   - Pixel-level IoU: 0.7999
# 평가 중: 4/10 - bfv3_grounded_sam2_results.json
#   - GT: 18, Pred: 18
#   - BBox: P=0.8333, R=0.8333, F1=0.8333
#   - Mask: P=0.6111, R=0.6111, F1=0.6111
#   - Combined: P=0.6667, R=0.6667, F1=0.6667
#   - Pixel-level IoU: 0.7319
# 평가 중: 5/10 - bfv4_grounded_sam2_results.json
# ...

# %% [markdown]
# # 2. rfv (robot-front-view)

# %%
from evaluator import CompleteGroundedSAM2Evaluator

# 파일 경로 설정
coco_annotations_path = "my_dataset/rfv/labels/rfv-labels_COCO-format.json"
grounded_sam2_results_dir = "outputs/PID4/CID5/rfv"

# 평가기 생성 및 실행
evaluator = CompleteGroundedSAM2Evaluator(coco_annotations_path, grounded_sam2_results_dir)
results = evaluator.run_evaluation()

if results:
    print("\n전체 평가가 완료되었습니다!")
else:
    print("\n평가 중 오류가 발생했습니다.")
# Out:
# 총 10개 이미지 평가 시작...
# ...
# 평가 중: 1/10 - rfv10_grounded_sam2_results.json
#   - GT: 16, Pred: 8
#   - BBox: P=0.7500, R=0.3750, F1=0.5000
#   - Mask: P=0.6250, R=0.3125, F1=0.4167
#   - Combined: P=0.6250, R=0.3125, F1=0.4167
#   - Pixel-level IoU: 0.4650
# 평가 중: 2/10 - rfv1_grounded_sam2_results.json
#   - GT: 5, Pred: 5
#   - BBox: P=0.6000, R=0.6000, F1=0.6000
#   - Mask: P=0.0000, R=0.0000, F1=0.0000
#   - Combined: P=0.0000, R=0.0000, F1=0.0000
#   - Pixel-level IoU: 0.0448
# 평가 중: 3/10 - rfv2_grounded_sam2_results.json
#   - GT: 13, Pred: 9
#   - BBox: P=0.7778, R=0.5385, F1=0.6364
#   - Mask: P=0.6667, R=0.4615, F1=0.5455
#   - Combined: P=0.6667, R=0.4615, F1=0.5455
#   - Pixel-level IoU: 0.5942
# 평가 중: 4/10 - rfv3_grounded_sam2_results.json
#   - GT: 13, Pred: 8
#   - BBox: P=0.7500, R=0.4615, F1=0.5714
#   - Mask: P=0.6250, R=0.3846, F1=0.4762
#   - Combined: P=0.6250, R=0.3846, F1=0.4762
#   - Pixel-level IoU: 0.5737
# 평가 중: 5/10 - rfv4_grounded_sam2_results.json
# ...
